# %% [markdown]
# #### Creating WORK BANK for creating features using raw sentences.

# %%
import pandas as pd
import openpyxl as op

# %%
# just to know what is the status of existing dataset.
df=pd.read_excel("training_intent_samples.xlsx")
df.count()
# Out:
# buyer_intent       134
# buyer_verbs         76
# products           653
# seller_intent      511
# seller_verbs       200
# ad_campaigns        42
# negative_verbs      79
# intent_suffixes     26
# dtype: int64

# %% [markdown]
# #### Intializing Data as Lists

# %%
buyer_intent = ['insisted', 'hunts', 'exclusive timepieces', 'online rare bookstores', 'hybrid and electric car models', 'budget-conscious', 'looking', 'buy', 'is considering', 'Interested', 'is obtaining', 'thrilled', 'Thinking about', 'comparing specifications', 'invests in', 'is shopping', 'assistance', 'audiophile forums', 'international watch auctions', 'unique and promising pieces', 'environmentally conscious mindset', 'Researching to findshops', 'is buying', 'loves to shop', 'will invest in', 'wants to', 'hunts for', 'enhance my travel experience', 'purchases', 'bibliophiles', 'will want to', 'researching the real estate market', 'flagship smartphone', 'is undering', 'loyal', 'purchase', 'obtain', 'will hunt for', 'study consumer reports', 'want', 'horological experts', 'dedicated audiophile', 'acquires unique', 'horological manufacturers', 'shops for', 'craftsmanship and innovationbuy', 'reading expert reviews', 'professional-grade cookware', 'usually unders', 'savvy', 'orders', 'requested', 'will buy', 'obtains', 'order', 'is purchasing', 'Negotiating', 'culinary arts', 'unders', 'get', 'Planning', 'is hunting', 'rare antique timepieces', 'will under', 'buys', 'Eager to find', 'high-fidelity audio equipment', 'Searching for', 'is wanting', 'rare and limited-edition books', 'return', 'interested', 'will shop for', 'emerging artists', 'cross-country road trip', 'eco-friendly vehicle options', 'under', 'make an investment', 'acquire', 'discerning', 'gets', 'is hunting for', 'will acquire', 'is acquiring', 'considering', 'avid art connoisseur', 'searching', 'versatile and robust recreational vehicle', 'reservation', 'shops', 'shop', 'is browsing', 'is getting', 'is ordering', 'Considering', 'will order', 'high-end kitchen appliance showrooms', 'eco-friendly features', 'long-term financial goals', 'currently undering', 'is looking', 'Exploring', 'is investing in', 'different eras', 'thinkingwill want', 'supporting', 'is shopping for', 'is under', 'Contemplating the idea of', 'eagerly', 'shop for', 'acquires', 'wants to purchase', 'hunt for', 'compared', 'On the lookout for', 'gets all', 'prefers', 'wants', 'reviewed', 'will shop', 'is interested', 'will get', 'valuable literary treasures', 'will hunt', 'wants to buy', 'buying', 'is comparing', 'demanding professional needs', 'invest in', 'sustainable lifestyle', 'high-end condominium', 'dream home audio setup', 'will obtain', 'will purchase']

buyer_verbs = ['insisted', 'planning', 'In the market forresearching', 'looking', 'buy', 'thrilled', 'assistance', 'Find', 'hunting', 'Buy', 'inspected', 'delve', 'Invest in', 'invest', 'warranty', 'purchase', 'obtain', 'investing in', 'make', 'exploring', 'want', 'ordering', 'afford', 'hunting for', 'scour', 'order', 'look', 'Negotiating', 'values', 'unders', 'get', 'buys', 'love', 'undering', 'Acquire', 'return', 'Looking for opportunities to', 'reading', 'upgrade', 'interested', 'under', 'shopping for', 'acquire', 'obtaining', 'consulting', 'browse', 'considering', 'searching', 'reservation', 'Explore', 'Purchase', 'shop', 'eager', 'consider', 'Aiming to', 'compare', 'supporting', 'comparing', 'knows', 'shop for', 'hunt for', 'compared', 'thinking', 'identifyingbuy', 'study', 'prefers', 'wants', 'getting', 'reviewed', 'Upgrade to', 'shopping', 'buying', 'engaging', 'acquiring', 'invest in', 'purchasing', 'hunt']

products = ['Kitchen Appliance', 'Baby Food Maker Parts and Accessories', 'exclusive timepiecesreview', 'kitchenare', 'Baby Food Making Vegan Bread', 'Fans', 'Pet', 'Gaming Console', 'Pots and Pans', 'Baby Food Making Keto Bread', 'Baby Food Making Non-GMO Bread', 'raw materials', 'Baby Food Making Formulas', 'Necklace', 'Camping Tent', 'Baby Food Making Equipment', 'Baby Food Cookbooks', 'Phone Case', 'Baby Food Containers and Storage', 'Travel Adapter', 'Board Games and Puzzles', 'Sofa set', 'Portable power bank', 'event planning', 'Baby Rug', 'Baby Food Making Rye Bread', 'arrival', 'Educational Books and Toys for Kids', 'Coin', 'Accessories', 'Baby Food Making Whole Grain Bread', 'Baby Food Making Combinations', 'Baby Food Making Challah', 'Video Game', 'feedback', 'vintage guitar', 'Art', 'Hiking Boot', 'Lumber', 'Bed Linens', 'Baby Food Making Pancakes', 'Pajamas', 'Car trunk organizer', 'Baby Bottle Brushes', 'Salt', 'Baby Food Making Cupcakes', 'Educational Toys', 'Gift', 'Smartwatch', 'Power Tools', 'Fishing Equipment', 'Beauty Product', 'Vegetables', 'Baby Winter Clothes', 'Camping Accessories', 'Baby Food Making Feasts', 'customer', 'Coffee machine', 'Costumes', 'electronics', 'handmade jewelry', 'rare antique timepieces', 'Stuffed Animal', "Chef's knife set", 'Car Accessories', 'Baby Food Making Lunches', 'Lawnmower', 'rare and limited-edition books', 'Baby Food Making Tips', 'car', 'Cycle', 'Baby Food Making Brownies', 'Baby Food Making Baguette', 'Baby Food Making Products', 'Home Decor', 'Home Décor Items', 'Electric standing desk', 'Headphones', 'headphones', 'beauty products', 'Baby Food Making Rolls', 'Baby Food Making Low-Carb Bread', 'Scrabble', 'Baby Food Making Tortillas', 'Baby Food Making English Muffins', 'discount', 'contemporary art', 'Analog Watch', 'Appliances', 'Baby Shoes', 'Baby Food Spoons', 'appliance', 'Baby Food Making Solutions', 'gaming console', 'CRM system', 'artwork', 'Baby Food Making Techniques', 'Finance', 'Yoga Strap', 'Maternity Clothing', 'Baby Food Storage', 'Baby Food Preparation Tools', 'Kitchenware', 'Lighting Fixtures', 'Novel', 'staff', 'Swimming Pool Supplies', 'Collectibles', 'Downloads', 'Planter', 'Backpack', 'Milk', 'Cereal', 'Sports Equipment', 'Bathroom Accessories', 'earbuds', 'Synthesizer', 'Toaster', 'Jean', 'Pet Bed', 'Musical Instruments', 'dress', 'machinery', 'Microphone', 'option', 'Baby Food Making Appliances', 'Baby Plates', 'Shovel', 'Baby Food Making Ancient Grain Breadsmartphone', 'Heel', 'Cutlery', 'Bicycle', 'Kitchen island', 'Hardware', 'Computer Accessories', 'Baby Food Freezer Storage', 'Office Supplies', 'Storage Solution', 'subscription', 'Towels', 'newsletter', 'Baby Food Making Snacks', 'Car Battery', 'Rattles', 'Sectional sofainsurance policy', 'Baby Food Making Sweets', 'Makeup Brushes and Tools', 'Baby Food Making Dinners', 'IT support services', 'Microwave', 'Gaming keyboard and mouse', 'Baby Food Making Bagels', 'item', 'Baby Food Jars', 'Baby Food Making Essentials', 'Baby Food Making Ciabatta', 'Skincare Product', 'Telescope', 'Science Kit', 'Baby Spoons', 'Uniforms & Workwear', 'Pulses', 'Baby Food Making Tools', 'loyalty', 'homemade skincare products', 'Construction Toy', 'Wearable Technology', 'Cookware', 'Violin', 'Baby Food Making Roti', 'Sports', 'Baby Food Making Breakfasts', 'Phone Accessories', 'Playmat', 'Elliptical Trainer', 'Baby Food Making Dishes', 'Alarm', 'Caps', 'Snacks', 'Curtains', 'Baby Food Making Scones', 'Baby Bottle Holders', 'Craft Kit', 'Security Camera', 'Household Appliances', 'Musical Keyboard', 'Washing Machine', 'handcrafted furniture', 'recreational vehicle', 'Gaming Accessories', 'Tea', 'Baby Food Making Waffles', 'Baby Strollers', 'Board Game', 'Bicycles and Accessories', 'Treadmill', 'Baby Food Making Crumpets', 'Beauty Products', 'Baby Food Making Donuts', 'Baby Food Making Sets', 'Pressure Cooker', 'Baby Food Making Advancements', 'literature', 'Baby Food Making Banquets', 'catalog', 'Consumer Electronics', 'Hiking backpack', 'Baby Diapers', 'Drone', 'Educational Game', 'Outdoor Gear', 'Baby Bath Toys', 'Baby Food Making Focaccia', 'Baby Food Cookbooks and Recipes', 'Fitness Equipment', 'Baby Food Making Hacks', 'Guitar', 'laptop', 'Noise-canceling headphones', 'Vacuum Cleaners', 'Baby Monitor', 'Baby Food', 'Baby Grooming Kits', 'Baby Food Making Multigrain Bread', 'Tennis Racket', 'Personal Hygiene Essentials', 'groceries', 'Baby Food Blenders and Processors', 'Health Supplements', 'Baby Wipes', 'Baby Food Making Gluten-Free Bread', 'office supplies', 'eco-friendly vehicle options', 'Electronics Accessories', 'Baby Food Making Artificial-Free Bread', 'Baby Socks', 'console', 'Baby Food Making Supplies', 'Toiletry', 'Trash Can', 'Butter', 'Baby Food Pouch Spoons', 'software solutions', 'Baby Bedding Set', 'Camping Gear', 'Baby Food Storage Trays', 'Vitamin', 'Baby Food Making High-Fiber Bread', 'Baby Food Steamers and Cookers', 'Stamp', 'Mobile Phone', 'Makeup', 'Ethnic & Traditional Clothing', 'Baby Food Warmers and Sterilizers', 'Laundry Supply', 'Craft Supplies', 'Electric guitar', 'Specialty Apparel', 'Baby Food Grinders', 'service', 'Vintage Toy', 'Towel', 'Baby Food Making Innovations', 'Candle', 'Fashion Accessories', 'Basketball', 'Chess Set', 'Baby Food Making Kits', 'Boot', 'quality', 'Art Supplies for Kids', 'speakers', 'Wall Art', 'Toys', 'books', 'company', 'Baby Food Making Pita', 'gardening tools', 'Cryptocurrencie', 'Fitness tracker', 'Yoga Accessories', 'Cordless vacuum cleaner', 'Baby Toys', 'Webcam', 'Haircare Product', 'Kitchen Appliances', 'Utensils', 'Baby Food Steamers', 'Stationery', 'Office Furniture', 'investment opportunities', 'Ring', 'Art Supplies', 'Small Appliances', 'Lighting Fixture', 'Cosmetics', 'Baby Food Making Organic Bread', 'Bed Linen', 'Cleaning Supply', 'web design services', 'Electric toothbrush', 'Induction cooktop', 'Sportswear', 'Workout Program', 'Coffee Machine', 'Sports Bra', 'Fitness Tracker', 'Washing machine', 'Baby Food Making Pretzels', 'Musical Equipment Accessories', 'Pet Food', 'Baby Food Making Confections', 'Baby Food Making Paleo Bread', 'Toys and Games', 'School Supplies', 'Baby Onesies', 'Bowls', 'Cycling Accessories', 'Baby Food Making Cakes', 'Hair Straighteners and Curling Irons', 'Brush', 'Textbook', 'Baby Food Making Natural Bread', 'Baby Changing Tables', 'Cleaning Supplies', 'Home Appliance', 'Party Supplies', 'Graphics card', 'Baby Bouncer', 'Neck Pillow', 'Sporting Goods', 'Baby Walker', 'Smart home thermostat', 'Cooking Oil', 'Customised Gifts', 'brand', 'External hard drive', 'Wheat Flour', 'Apple Watch', 'Bedding', 'Baby Food Mills', 'Baby Food Making Utensils', 'Baby Clothing Sets', 'Shirt', 'Baby Food Making Preservative-Free Bread', 'Action Figure', 'Home Improvement Supplies', 'flagship smartphone', 'Hunting and Fishing Gear', 'Baby Healthcare Kits', 'Baby Clothing and Accessories', 'Smart Thermostat', 'Digital camera', 'Sectional sofa', 'Workout Legging', 'Book', 'Educational Books', 'Baby Formula', 'Furniture', 'category', 'Car', 'Paintings and Art Prints', 'Dollhouse', 'Booties', 'Baby Food Making Discoveries', 'antique book collection', 'product', 'Power generator', 'Paint', 'Baby Swing', 'Home blender', 'Tire', 'Sugar', 'Lentils', 'Camera lens', 'Storage Solutions', 'Pot', 'Sneaker', 'DJ controller', 'Bread', 'Baby Teethers', 'Baby Car Seats', 'strategic assets', 'Charger', 'Gaming laptop', 'Stroller', 'Pen', 'Baby Food Mashers', 'office equipment', 'Fitness DVD', 'Espresso machine', 'Equipment', 'Kitchen Knife', 'Smart home security system', 'Amplifier', 'Baby Food Making Dairy-Free Bread', 'Desk Organizer', 'vintage clothing collection', 'Baby Bottle Sterilizers', 'new', 'Dinnerware', 'Refrigerator', 'Baby Hats', 'Dishwasher', 'Baby Food Making Cuisine', 'gaming', 'Baby Food Making Baked Goods', 'Sunglasses', 'Wardrobe', 'Coffee Maker', 'Exercise Machines', 'Insurance', 'tools', 'Baby Food Making Whole Wheat Bread', 'Baby Food Making Naan', 'consultation', 'Rice', 'Smart Home Devices', 'Appliance', 'clothes', 'Baby Food Steamers and Blenders', 'Baby Food Making Pastries', 'furniture', 'Digital Camera', 'Camera tripod', 'software', 'Screen Protector', 'Baby Bottle Drying Racks', 'Baby Food Makers and Mixers', 'Baby Food Making Ideas', 'Baby Food Processors', 'Baby Food Making Sugar-Free Bread', 'Backpacks for Kids', 'Baby Food Pouch Fillers', 'Baby Food Making Necessities', 'Cookbooks and Recipe Books', 'Computer Accessories & Software', 'Vacuum Cleaner', 'Baby Food Making Desserts', 'Baby Food Making Tricks', 'Fitbit', 'Protein Powder', 'Baby Food Making Muffins', 'Balloon', 'recycled fashion items', 'Video Game Title', 'Trash Cans', 'Baby Food Squeezable Pouches', 'Mirrorless Camera', 'Baby Food Pouches', 'uniforms', 'Baby Food Making Soy-Free Bread', 'Standing desk', 'Automotive', 'Vase', 'Vacuum cleaner', 'Baby Food Making Cookies', 'Yoga Block', 'Headphone', 'Dress', 'Footwear', 'shipment', 'Closet organizer', 'corporate gifts', '4K projector', 'Baby Gear', 'Tea Set', 'Apparel', 'Baby Food Making Lavash', 'Baby Food Containers', 'high-end condominium', 'Baby Food Making Nut-Free Bread', 'High Demand Products to Sell', 'tracking', 'Baby Bathtubs', 'Party Favor', 'Home Security System', 'Baby Food Making Flatbreads', 'Jewellery', 'Voice Assistant', 'Exercise Apparel', 'Telescope Accessories', 'Monopoly', 'Glassware', 'Baby Food Mixers', 'Baby Food Making Devices', 'real estate', 'handmade', 'supplier evaluation report', 'Baby Food Warmers', 'marketing services', 'Pot and Pan', 'Remote Control Toy', 'Pan', 'Watches', 'DSLR Camera', 'Spices', 'Baby Food Making Low-Calorie Bread', 'Fruits', 'Subscriptions', 'Books', 'Experience', 'Baby Food Grinders and Mills', 'Tickets', 'Baby Food Making Breakthroughs', 'Leather wallet', 'Travel Accessories', 'clearance', 'Baby Food Pouches and Accessories', 'Wall Clock', 'Fan', 'Turntable', 'Coffee', 'Baby Food Making Recipes', 'Blender', 'Eggs', 'Decoration', 'Sewing Machines and Supplies', 'Baby Food Making Ingredients', 'Mountain bike', 'home decor', 'Baby Food Making Biscuits', 'Automotive Parts', 'Cosplay Costumes & Accessories', 'Jewelry', 'Baby Food Makers', 'Intimate Apparel', 'Electronics', 'Alarm Clock', 'Baby Food Making Creations', 'pet supplies', "Kids' Clothing", 'professional-grade cookware', 'Notebook', 'Lunchboxes', 'Baby Carriers', 'Baby Food Making Flavors', 'Cleaning Items', 'Baby Food Making Croissants', 'Acoustic guitar', 'DSLR camera', 'Baby Food Making Strategies', 'inventory', 'Leash', 'Craft and Hobby Books', 'Baby Food Making Gadgets', 'Yoga Mat', 'Baby Bibs', 'Bathroom Accessory', 'Food', 'Bike', 'Toiletries', 'Camping tent', 'Baby Food Making Egg-Free Bread', 'Doll', 'Travel', 'Noise-canceling earbuds', 'Cookware set', 'Fish Oil', 'Microwave oven', 'Baby Food Making Cookery', 'Perfumes and Fragrances', 'Garmin', 'stationery', 'Baby Food Making Machines', 'high-fidelity audio equipment', 'Pickles', 'Baby Bottle Warmers', 'Gaming console', 'gift', 'consulting services', 'Projector', 'Sweets', 'gifts', 'Gardening Tools', 'Leather recliner chair', 'Curtain', 'Baby Food Making Developments', 'Education', 'Robotic vacuum cleaner', 'Baby Bottles', 'Diaper', 'Bracelet', 'Bathroom Stuffs', 'Fitness smartwatch', 'Shelf', 'business', 'Dal', 'Utensil', 'Keyboard', 'Earrings and Ear Jewelry', 'payment', 'Shelving', 'Fitness treadmill', 'deal', 'Baby Food Making Pies', 'Laundry Supplies', 'Baby Feeding Supplies', 'Baby Food Blenders', 'Baby Swimsuits', 'Baby Food Storage Containers', 'Clothing', 'Dumbbell', 'Convenience Foods', 'Pet Supplies', 'Baby Food Freezer Trays', 'Groceries', 'Puzzle', 'Canvas', 'Mic', 'Toy', 'Home Theater System', 'Baby Dresses', 'Baby Food Making Meals', 'Rowing Machine', 'Yoga Towel', 'Forks', 'Baby Pacifiers', 'Soundbar', 'Baby Food Making Treats', 'phone', 'Baby Food Making Bread', 'Baby Food Making Tarts', 'Baby Food Utensils and Accessories', 'Baby Potty Training', 'Baby Product', 'Running Shoe', 'High-definition projector', 'Sound system', 'Laptop', 'Cookbook', 'Digital Watch', 'Luggage', "Children's Books", 'Baby Crib', 'Baby Food Dispensers', 'Oil Filter', 'Baby High Chairs', 'Leather backpack', 'Golf Clubs and Golf Accessories', 'artisanal chocolatesselectionbooks', 'Baby Food Making Improvements', 'Baby Food Making Suppers', 'Smartphone', 'Baby Food Making Options', "Baby & Children's Clothing", 'Bluetooth Speaker', 'Telescopes and Binoculars', 'Teapot', 'Baby Food Making Varieties', 'collectible', 'Weightlifting Equipment', 'Small Appliance', 'Jam']

negative_verbs =  list(set(['had never', 'must not', "can't", 'Resist', "aren't", 'Reject', 'Abstain from', "don't want", "do notdoesn't want", 'though', "isn't", 'avoids', 'is rejecting', 'dont', 'Give up on', 'Disregard', "wouldn't", 'is refusing', 'is avoiding', "ain't got", 'will cancel', 'Decline', 'Forsake', 'was never', 'Abandon', 'refuse', 'Avoid', 'cannot', 'is canceling', 'refuses', "hadn't", 'rejects', "haven't", 'will refuserefuse', 'return', 'returns', 'Renounceavoid', 'Ignore', 'Dispose of', "couldn't", "won't", 'has never', 'even', "weren't", "ain't nobody", 'Cancel', 'is returning', 'reject', 'Surrender', 'Discontinue', 'will not', 'Terminate', 'is discontinuing', 'cancel', 'will reject', 'is never', 'discontinue', "didn't want", "shouldn't", "hasn't", 'will return', 'Refrain from', 'Dismiss', 'Shun', 'discontinues', 'cancels', 'will discontinue', 'are never', "wasn't", 'shall not', "don't", "ain't no", 'were never', 'despite', 'will avoid', 'Relinquish', "ain't none", 'although', 'have never', "ain't"  ]))    

ad_campaigns = list(set(['television campaign', 'influencer marketing campaignmarketing', 'cause marketing', 'advertising', 'support', 'promotional campaign', 'contribute', 'product launch campaign', 'radio campaign', 'brand awareness', 'online', 'participate', 'social media campaign', 'video', 'back', 'holiday campaign', 'print campaign', 'radio', 'advertising campaign', 'influencer marketing', 'television', 'seasonal campaign', 'print', 'online campaign', 'cause marketing campaign', 'content', 'content marketing campaign', 'social media', 'holiday', 'product launch', 'sales', 'digital campaign', 'campaign', 'promotion', 'rebranding campaign', 'seasonal', 'video campaign', 'brand awareness campaign', 'marketing campaign', 'digital', 'rebranding', 'email campaign', 'email']))

seller_verbs = list(set(['vend', 'will bundle', 'present', 'value', 'is supplying', 'highlights', 'will deal', 'will showcase', 'is exhibiting', 'is bargaining', 'will display', 'will sell', 'advertise', 'will present', 'is selling', 'bargain', 'resell', 'import', 'clearances', 'is restocking', 'presents', 'trade-in', 'shares', 'imports', 'is bundling', 'will auction off', 'know', 'offer up', 'initiate', 'is showcasing', 'bargains', 'will feature', 'clearance', 'accept', 'exhibits', 'is publishing', 'will retail', 'will offer', 'advertising campaign', 'exploring', 'showcase', 'export', 'exports', 'is highlighting', 'list', 'sells', 'is featuring', 'merchandises', 'provide', 'post', 'update', 'will share', 'listing', 'will pitch', 'is advertising', 'publishes', 'features', 'push', 'is discounting', 'providing', 'auctions', 'leave', 'inventory', 'will vend', 'posts', 'is wholesaling', 'will trade-in', 'markets', 'will wholesale', 'reward', 'will provide', 'promote', 'will push', 'discounts', 'sell', 'merchandise', 'deals', 'will bargain', 'will inventory', 'is showing', 'auctions off', 'will advertise', 'promotes', 'wholesales', 'restock', 'will distribute', 'is pushing', 'bundle', 'will promote', 'market', 'retail', 'communicate', 'is reselling', 'exhibit', 'is importing', 'is auctioning off', 'launching', 'pitches', 'will resell', 'will discountplanning', 'broadcasts', 'feature', 'is auctioning', 'will list', 'considering', 'is presenting', 'will import', 'inventories', 'will auction', 'discount', 'restocking', 'offers', 'deal', 'supplies', 'offers up', 'will post', 'specialize', 'stocks', 'broadcast', 'is clearing', 'resells', 'bundles', 'ship', 'shows', 'vends', 'auction', 'is dealing', 'showcases', 'supply', 'is offering', 'is trading-in', 'publicity campaign', 'will offer up', 'marketing campaign', 'publish', 'pitch', 'open', 'will exhibit', 'pushes', 'featureSell', 'wholesale', 'will export', 'stock', 'is exporting', 'contemplating', 'is stocking', 'offering', 'trades-in', 'highlight', 'will stock', 'share', 'is inventorying', 'show', 'deliver', 'will restock', 'lists', 'is broadcasting', 'subscribe', 'is distributing', 'will highlight', 'will trade', 'engage', 'is retailing', 'is providing', 'customize', 'will broadcast', 'trade', 'find', 'offer', 'will merchandise', 'thinking', 'is pitching', 'is merchandising', 'is listing', 'will show', 'will publish', 'is sharing', 'is marketing', 'is promoting', 'will clear', 'auction off', 'is trading', 'seller_verbs', 'is vending', 'expand', 'open to', 'distribute', 'will market', 'prioritize', 'will supply', 'is posting', 'trades', 'retails', 'display', 'is offering up', 'provides', 'restocks', 'distributes', 'displays', 'is displaying', 'advertises']))

# %%
buyer_intent = ['insisted', 'hunts', 'exclusive timepieces', 'online rare bookstores', 'hybrid and electric car models', 'budget-conscious', 'looking', 'buy', 'is considering', 'Interested', 'is obtaining', 'thrilled', 'Thinking about', 'comparing specifications', 'invests in', 'is shopping', 'assistance', 'audiophile forums', 'international watch auctions', 'unique and promising pieces', 'environmentally conscious mindset', 'Researching to findshops', 'is buying', 'loves to shop', 'will invest in', 'wants to', 'hunts for', 'enhance my travel experience', 'purchases', 'bibliophiles', 'will want to', 'researching the real estate market', 'flagship smartphone', 'is undering', 'loyal', 'purchase', 'obtain', 'will hunt for', 'study consumer reports', 'want', 'horological experts', 'dedicated audiophile', 'acquires unique', 'horological manufacturers', 'shops for', 'craftsmanship and innovationbuy', 'reading expert reviews', 'professional-grade cookware', 'usually unders', 'savvy', 'orders', 'requested', 'will buy', 'obtains', 'order', 'is purchasing', 'Negotiating', 'culinary arts', 'unders', 'get', 'Planning', 'is hunting', 'rare antique timepieces', 'will under', 'buys', 'Eager to find', 'high-fidelity audio equipment', 'Searching for', 'is wanting', 'rare and limited-edition books', 'return', 'interested', 'will shop for', 'emerging artists', 'cross-country road trip', 'eco-friendly vehicle options', 'under', 'make an investment', 'acquire', 'discerning', 'gets', 'is hunting for', 'will acquire', 'is acquiring', 'considering', 'avid art connoisseur', 'searching', 'versatile and robust recreational vehicle', 'reservation', 'shops', 'shop', 'is browsing', 'is getting', 'is ordering', 'Considering', 'will order', 'high-end kitchen appliance showrooms', 'eco-friendly features', 'long-term financial goals', 'currently undering', 'is looking', 'Exploring', 'is investing in', 'different eras', 'thinkingwill want', 'supporting', 'is shopping for', 'is under', 'Contemplating the idea of', 'eagerly', 'shop for', 'acquires', 'wants to purchase', 'hunt for', 'compared', 'On the lookout for', 'gets all', 'prefers', 'wants', 'reviewed', 'will shop', 'is interested', 'will get', 'valuable literary treasures', 'will hunt', 'wants to buy', 'buying', 'is comparing', 'demanding professional needs', 'invest in', 'sustainable lifestyle', 'high-end condominium', 'dream home audio setup', 'will obtain', 'will purchase']

buyer_verbs = ['insisted', 'planning', 'In the market forresearching', 'looking', 'buy', 'thrilled', 'assistance', 'Find', 'hunting', 'Buy', 'inspected', 'delve', 'Invest in', 'invest', 'warranty', 'purchase', 'obtain', 'investing in', 'make', 'exploring', 'want', 'ordering', 'afford', 'hunting for', 'scour', 'order', 'look', 'Negotiating', 'values', 'unders', 'get', 'buys', 'love', 'undering', 'Acquire', 'return', 'Looking for opportunities to', 'reading', 'upgrade', 'interested', 'under', 'shopping for', 'acquire', 'obtaining', 'consulting', 'browse', 'considering', 'searching', 'reservation', 'Explore', 'Purchase', 'shop', 'eager', 'consider', 'Aiming to', 'compare', 'supporting', 'comparing', 'knows', 'shop for', 'hunt for', 'compared', 'thinking', 'identifyingbuy', 'study', 'prefers', 'wants', 'getting', 'reviewed', 'Upgrade to', 'shopping', 'buying', 'engaging', 'acquiring', 'invest in', 'purchasing', 'hunt']

products = ['Kitchen Appliance', 'Baby Food Maker Parts and Accessories', 'exclusive timepiecesreview', 'kitchenare', 'Baby Food Making Vegan Bread', 'Fans', 'Pet', 'Gaming Console', 'Pots and Pans', 'Baby Food Making Keto Bread', 'Baby Food Making Non-GMO Bread', 'raw materials', 'Baby Food Making Formulas', 'Necklace', 'Camping Tent', 'Baby Food Making Equipment', 'Baby Food Cookbooks', 'Phone Case', 'Baby Food Containers and Storage', 'Travel Adapter', 'Board Games and Puzzles', 'Sofa set', 'Portable power bank', 'event planning', 'Baby Rug', 'Baby Food Making Rye Bread', 'arrival', 'Educational Books and Toys for Kids', 'Coin', 'Accessories', 'Baby Food Making Whole Grain Bread', 'Baby Food Making Combinations', 'Baby Food Making Challah', 'Video Game', 'feedback', 'vintage guitar', 'Art', 'Hiking Boot', 'Lumber', 'Bed Linens', 'Baby Food Making Pancakes', 'Pajamas', 'Car trunk organizer', 'Baby Bottle Brushes', 'Salt', 'Baby Food Making Cupcakes', 'Educational Toys', 'Gift', 'Smartwatch', 'Power Tools', 'Fishing Equipment', 'Beauty Product', 'Vegetables', 'Baby Winter Clothes', 'Camping Accessories', 'Baby Food Making Feasts', 'customer', 'Coffee machine', 'Costumes', 'electronics', 'handmade jewelry', 'rare antique timepieces', 'Stuffed Animal', "Chef's knife set", 'Car Accessories', 'Baby Food Making Lunches', 'Lawnmower', 'rare and limited-edition books', 'Baby Food Making Tips', 'car', 'Cycle', 'Baby Food Making Brownies', 'Baby Food Making Baguette', 'Baby Food Making Products', 'Home Decor', 'Home Décor Items', 'Electric standing desk', 'Headphones', 'headphones', 'beauty products', 'Baby Food Making Rolls', 'Baby Food Making Low-Carb Bread', 'Scrabble', 'Baby Food Making Tortillas', 'Baby Food Making English Muffins', 'discount', 'contemporary art', 'Analog Watch', 'Appliances', 'Baby Shoes', 'Baby Food Spoons', 'appliance', 'Baby Food Making Solutions', 'gaming console', 'CRM system', 'artwork', 'Baby Food Making Techniques', 'Finance', 'Yoga Strap', 'Maternity Clothing', 'Baby Food Storage', 'Baby Food Preparation Tools', 'Kitchenware', 'Lighting Fixtures', 'Novel', 'staff', 'Swimming Pool Supplies', 'Collectibles', 'Downloads', 'Planter', 'Backpack', 'Milk', 'Cereal', 'Sports Equipment', 'Bathroom Accessories', 'earbuds', 'Synthesizer', 'Toaster', 'Jean', 'Pet Bed', 'Musical Instruments', 'dress', 'machinery', 'Microphone', 'option', 'Baby Food Making Appliances', 'Baby Plates', 'Shovel', 'Baby Food Making Ancient Grain Breadsmartphone', 'Heel', 'Cutlery', 'Bicycle', 'Kitchen island', 'Hardware', 'Computer Accessories', 'Baby Food Freezer Storage', 'Office Supplies', 'Storage Solution', 'subscription', 'Towels', 'newsletter', 'Baby Food Making Snacks', 'Car Battery', 'Rattles', 'Sectional sofainsurance policy', 'Baby Food Making Sweets', 'Makeup Brushes and Tools', 'Baby Food Making Dinners', 'IT support services', 'Microwave', 'Gaming keyboard and mouse', 'Baby Food Making Bagels', 'item', 'Baby Food Jars', 'Baby Food Making Essentials', 'Baby Food Making Ciabatta', 'Skincare Product', 'Telescope', 'Science Kit', 'Baby Spoons', 'Uniforms & Workwear', 'Pulses', 'Baby Food Making Tools', 'loyalty', 'homemade skincare products', 'Construction Toy', 'Wearable Technology', 'Cookware', 'Violin', 'Baby Food Making Roti', 'Sports', 'Baby Food Making Breakfasts', 'Phone Accessories', 'Playmat', 'Elliptical Trainer', 'Baby Food Making Dishes', 'Alarm', 'Caps', 'Snacks', 'Curtains', 'Baby Food Making Scones', 'Baby Bottle Holders', 'Craft Kit', 'Security Camera', 'Household Appliances', 'Musical Keyboard', 'Washing Machine', 'handcrafted furniture', 'recreational vehicle', 'Gaming Accessories', 'Tea', 'Baby Food Making Waffles', 'Baby Strollers', 'Board Game', 'Bicycles and Accessories', 'Treadmill', 'Baby Food Making Crumpets', 'Beauty Products', 'Baby Food Making Donuts', 'Baby Food Making Sets', 'Pressure Cooker', 'Baby Food Making Advancements', 'literature', 'Baby Food Making Banquets', 'catalog', 'Consumer Electronics', 'Hiking backpack', 'Baby Diapers', 'Drone', 'Educational Game', 'Outdoor Gear', 'Baby Bath Toys', 'Baby Food Making Focaccia', 'Baby Food Cookbooks and Recipes', 'Fitness Equipment', 'Baby Food Making Hacks', 'Guitar', 'laptop', 'Noise-canceling headphones', 'Vacuum Cleaners', 'Baby Monitor', 'Baby Food', 'Baby Grooming Kits', 'Baby Food Making Multigrain Bread', 'Tennis Racket', 'Personal Hygiene Essentials', 'groceries', 'Baby Food Blenders and Processors', 'Health Supplements', 'Baby Wipes', 'Baby Food Making Gluten-Free Bread', 'office supplies', 'eco-friendly vehicle options', 'Electronics Accessories', 'Baby Food Making Artificial-Free Bread', 'Baby Socks', 'console', 'Baby Food Making Supplies', 'Toiletry', 'Trash Can', 'Butter', 'Baby Food Pouch Spoons', 'software solutions', 'Baby Bedding Set', 'Camping Gear', 'Baby Food Storage Trays', 'Vitamin', 'Baby Food Making High-Fiber Bread', 'Baby Food Steamers and Cookers', 'Stamp', 'Mobile Phone', 'Makeup', 'Ethnic & Traditional Clothing', 'Baby Food Warmers and Sterilizers', 'Laundry Supply', 'Craft Supplies', 'Electric guitar', 'Specialty Apparel', 'Baby Food Grinders', 'service', 'Vintage Toy', 'Towel', 'Baby Food Making Innovations', 'Candle', 'Fashion Accessories', 'Basketball', 'Chess Set', 'Baby Food Making Kits', 'Boot', 'quality', 'Art Supplies for Kids', 'speakers', 'Wall Art', 'Toys', 'books', 'company', 'Baby Food Making Pita', 'gardening tools', 'Cryptocurrencie', 'Fitness tracker', 'Yoga Accessories', 'Cordless vacuum cleaner', 'Baby Toys', 'Webcam', 'Haircare Product', 'Kitchen Appliances', 'Utensils', 'Baby Food Steamers', 'Stationery', 'Office Furniture', 'investment opportunities', 'Ring', 'Art Supplies', 'Small Appliances', 'Lighting Fixture', 'Cosmetics', 'Baby Food Making Organic Bread', 'Bed Linen', 'Cleaning Supply', 'web design services', 'Electric toothbrush', 'Induction cooktop', 'Sportswear', 'Workout Program', 'Coffee Machine', 'Sports Bra', 'Fitness Tracker', 'Washing machine', 'Baby Food Making Pretzels', 'Musical Equipment Accessories', 'Pet Food', 'Baby Food Making Confections', 'Baby Food Making Paleo Bread', 'Toys and Games', 'School Supplies', 'Baby Onesies', 'Bowls', 'Cycling Accessories', 'Baby Food Making Cakes', 'Hair Straighteners and Curling Irons', 'Brush', 'Textbook', 'Baby Food Making Natural Bread', 'Baby Changing Tables', 'Cleaning Supplies', 'Home Appliance', 'Party Supplies', 'Graphics card', 'Baby Bouncer', 'Neck Pillow', 'Sporting Goods', 'Baby Walker', 'Smart home thermostat', 'Cooking Oil', 'Customised Gifts', 'brand', 'External hard drive', 'Wheat Flour', 'Apple Watch', 'Bedding', 'Baby Food Mills', 'Baby Food Making Utensils', 'Baby Clothing Sets', 'Shirt', 'Baby Food Making Preservative-Free Bread', 'Action Figure', 'Home Improvement Supplies', 'flagship smartphone', 'Hunting and Fishing Gear', 'Baby Healthcare Kits', 'Baby Clothing and Accessories', 'Smart Thermostat', 'Digital camera', 'Sectional sofa', 'Workout Legging', 'Book', 'Educational Books', 'Baby Formula', 'Furniture', 'category', 'Car', 'Paintings and Art Prints', 'Dollhouse', 'Booties', 'Baby Food Making Discoveries', 'antique book collection', 'product', 'Power generator', 'Paint', 'Baby Swing', 'Home blender', 'Tire', 'Sugar', 'Lentils', 'Camera lens', 'Storage Solutions', 'Pot', 'Sneaker', 'DJ controller', 'Bread', 'Baby Teethers', 'Baby Car Seats', 'strategic assets', 'Charger', 'Gaming laptop', 'Stroller', 'Pen', 'Baby Food Mashers', 'office equipment', 'Fitness DVD', 'Espresso machine', 'Equipment', 'Kitchen Knife', 'Smart home security system', 'Amplifier', 'Baby Food Making Dairy-Free Bread', 'Desk Organizer', 'vintage clothing collection', 'Baby Bottle Sterilizers', 'new', 'Dinnerware', 'Refrigerator', 'Baby Hats', 'Dishwasher', 'Baby Food Making Cuisine', 'gaming', 'Baby Food Making Baked Goods', 'Sunglasses', 'Wardrobe', 'Coffee Maker', 'Exercise Machines', 'Insurance', 'tools', 'Baby Food Making Whole Wheat Bread', 'Baby Food Making Naan', 'consultation', 'Rice', 'Smart Home Devices', 'Appliance', 'clothes', 'Baby Food Steamers and Blenders', 'Baby Food Making Pastries', 'furniture', 'Digital Camera', 'Camera tripod', 'software', 'Screen Protector', 'Baby Bottle Drying Racks', 'Baby Food Makers and Mixers', 'Baby Food Making Ideas', 'Baby Food Processors', 'Baby Food Making Sugar-Free Bread', 'Backpacks for Kids', 'Baby Food Pouch Fillers', 'Baby Food Making Necessities', 'Cookbooks and Recipe Books', 'Computer Accessories & Software', 'Vacuum Cleaner', 'Baby Food Making Desserts', 'Baby Food Making Tricks', 'Fitbit', 'Protein Powder', 'Baby Food Making Muffins', 'Balloon', 'recycled fashion items', 'Video Game Title', 'Trash Cans', 'Baby Food Squeezable Pouches', 'Mirrorless Camera', 'Baby Food Pouches', 'uniforms', 'Baby Food Making Soy-Free Bread', 'Standing desk', 'Automotive', 'Vase', 'Vacuum cleaner', 'Baby Food Making Cookies', 'Yoga Block', 'Headphone', 'Dress', 'Footwear', 'shipment', 'Closet organizer', 'corporate gifts', '4K projector', 'Baby Gear', 'Tea Set', 'Apparel', 'Baby Food Making Lavash', 'Baby Food Containers', 'high-end condominium', 'Baby Food Making Nut-Free Bread', 'High Demand Products to Sell', 'tracking', 'Baby Bathtubs', 'Party Favor', 'Home Security System', 'Baby Food Making Flatbreads', 'Jewellery', 'Voice Assistant', 'Exercise Apparel', 'Telescope Accessories', 'Monopoly', 'Glassware', 'Baby Food Mixers', 'Baby Food Making Devices', 'real estate', 'handmade', 'supplier evaluation report', 'Baby Food Warmers', 'marketing services', 'Pot and Pan', 'Remote Control Toy', 'Pan', 'Watches', 'DSLR Camera', 'Spices', 'Baby Food Making Low-Calorie Bread', 'Fruits', 'Subscriptions', 'Books', 'Experience', 'Baby Food Grinders and Mills', 'Tickets', 'Baby Food Making Breakthroughs', 'Leather wallet', 'Travel Accessories', 'clearance', 'Baby Food Pouches and Accessories', 'Wall Clock', 'Fan', 'Turntable', 'Coffee', 'Baby Food Making Recipes', 'Blender', 'Eggs', 'Decoration', 'Sewing Machines and Supplies', 'Baby Food Making Ingredients', 'Mountain bike', 'home decor', 'Baby Food Making Biscuits', 'Automotive Parts', 'Cosplay Costumes & Accessories', 'Jewelry', 'Baby Food Makers', 'Intimate Apparel', 'Electronics', 'Alarm Clock', 'Baby Food Making Creations', 'pet supplies', "Kids' Clothing", 'professional-grade cookware', 'Notebook', 'Lunchboxes', 'Baby Carriers', 'Baby Food Making Flavors', 'Cleaning Items', 'Baby Food Making Croissants', 'Acoustic guitar', 'DSLR camera', 'Baby Food Making Strategies', 'inventory', 'Leash', 'Craft and Hobby Books', 'Baby Food Making Gadgets', 'Yoga Mat', 'Baby Bibs', 'Bathroom Accessory', 'Food', 'Bike', 'Toiletries', 'Camping tent', 'Baby Food Making Egg-Free Bread', 'Doll', 'Travel', 'Noise-canceling earbuds', 'Cookware set', 'Fish Oil', 'Microwave oven', 'Baby Food Making Cookery', 'Perfumes and Fragrances', 'Garmin', 'stationery', 'Baby Food Making Machines', 'high-fidelity audio equipment', 'Pickles', 'Baby Bottle Warmers', 'Gaming console', 'gift', 'consulting services', 'Projector', 'Sweets', 'gifts', 'Gardening Tools', 'Leather recliner chair', 'Curtain', 'Baby Food Making Developments', 'Education', 'Robotic vacuum cleaner', 'Baby Bottles', 'Diaper', 'Bracelet', 'Bathroom Stuffs', 'Fitness smartwatch', 'Shelf', 'business', 'Dal', 'Utensil', 'Keyboard', 'Earrings and Ear Jewelry', 'payment', 'Shelving', 'Fitness treadmill', 'deal', 'Baby Food Making Pies', 'Laundry Supplies', 'Baby Feeding Supplies', 'Baby Food Blenders', 'Baby Swimsuits', 'Baby Food Storage Containers', 'Clothing', 'Dumbbell', 'Convenience Foods', 'Pet Supplies', 'Baby Food Freezer Trays', 'Groceries', 'Puzzle', 'Canvas', 'Mic', 'Toy', 'Home Theater System', 'Baby Dresses', 'Baby Food Making Meals', 'Rowing Machine', 'Yoga Towel', 'Forks', 'Baby Pacifiers', 'Soundbar', 'Baby Food Making Treats', 'phone', 'Baby Food Making Bread', 'Baby Food Making Tarts', 'Baby Food Utensils and Accessories', 'Baby Potty Training', 'Baby Product', 'Running Shoe', 'High-definition projector', 'Sound system', 'Laptop', 'Cookbook', 'Digital Watch', 'Luggage', "Children's Books", 'Baby Crib', 'Baby Food Dispensers', 'Oil Filter', 'Baby High Chairs', 'Leather backpack', 'Golf Clubs and Golf Accessories', 'artisanal chocolatesselectionbooks', 'Baby Food Making Improvements', 'Baby Food Making Suppers', 'Smartphone', 'Baby Food Making Options', "Baby & Children's Clothing", 'Bluetooth Speaker', 'Telescopes and Binoculars', 'Teapot', 'Baby Food Making Varieties', 'collectible', 'Weightlifting Equipment', 'Small Appliance', 'Jam']

negative_verbs =  list(set(['had never', 'must not', "can't", 'Resist', "aren't", 'Reject', 'Abstain from', "don't want", "do notdoesn't want", 'though', "isn't", 'avoids', 'is rejecting', 'dont', 'Give up on', 'Disregard', "wouldn't", 'is refusing', 'is avoiding', "ain't got", 'will cancel', 'Decline', 'Forsake', 'was never', 'Abandon', 'refuse', 'Avoid', 'cannot', 'is canceling', 'refuses', "hadn't", 'rejects', "haven't", 'will refuserefuse', 'return', 'returns', 'Renounceavoid', 'Ignore', 'Dispose of', "couldn't", "won't", 'has never', 'even', "weren't", "ain't nobody", 'Cancel', 'is returning', 'reject', 'Surrender', 'Discontinue', 'will not', 'Terminate', 'is discontinuing', 'cancel', 'will reject', 'is never', 'discontinue', "didn't want", "shouldn't", "hasn't", 'will return', 'Refrain from', 'Dismiss', 'Shun', 'discontinues', 'cancels', 'will discontinue', 'are never', "wasn't", 'shall not', "don't", "ain't no", 'were never', 'despite', 'will avoid', 'Relinquish', "ain't none", 'although', 'have never', "ain't"  ]))    

ad_campaigns = list(set(['television campaign', 'influencer marketing campaignmarketing', 'cause marketing', 'advertising', 'support', 'promotional campaign', 'contribute', 'product launch campaign', 'radio campaign', 'brand awareness', 'online', 'participate', 'social media campaign', 'video', 'back', 'holiday campaign', 'print campaign', 'radio', 'advertising campaign', 'influencer marketing', 'television', 'seasonal campaign', 'print', 'online campaign', 'cause marketing campaign', 'content', 'content marketing campaign', 'social media', 'holiday', 'product launch', 'sales', 'digital campaign', 'campaign', 'promotion', 'rebranding campaign', 'seasonal', 'video campaign', 'brand awareness campaign', 'marketing campaign', 'digital', 'rebranding', 'email campaign', 'email']))

seller_verbs = list(set(['vend', 'will bundle', 'present', 'value', 'is supplying', 'highlights', 'will deal', 'will showcase', 'is exhibiting', 'is bargaining', 'will display', 'will sell', 'advertise', 'will present', 'is selling', 'bargain', 'resell', 'import', 'clearances', 'is restocking', 'presents', 'trade-in', 'shares', 'imports', 'is bundling', 'will auction off', 'know', 'offer up', 'initiate', 'is showcasing', 'bargains', 'will feature', 'clearance', 'accept', 'exhibits', 'is publishing', 'will retail', 'will offer', 'advertising campaign', 'exploring', 'showcase', 'export', 'exports', 'is highlighting', 'list', 'sells', 'is featuring', 'merchandises', 'provide', 'post', 'update', 'will share', 'listing', 'will pitch', 'is advertising', 'publishes', 'features', 'push', 'is discounting', 'providing', 'auctions', 'leave', 'inventory', 'will vend', 'posts', 'is wholesaling', 'will trade-in', 'markets', 'will wholesale', 'reward', 'will provide', 'promote', 'will push', 'discounts', 'sell', 'merchandise', 'deals', 'will bargain', 'will inventory', 'is showing', 'auctions off', 'will advertise', 'promotes', 'wholesales', 'restock', 'will distribute', 'is pushing', 'bundle', 'will promote', 'market', 'retail', 'communicate', 'is reselling', 'exhibit', 'is importing', 'is auctioning off', 'launching', 'pitches', 'will resell', 'will discountplanning', 'broadcasts', 'feature', 'is auctioning', 'will list', 'considering', 'is presenting', 'will import', 'inventories', 'will auction', 'discount', 'restocking', 'offers', 'deal', 'supplies', 'offers up', 'will post', 'specialize', 'stocks', 'broadcast', 'is clearing', 'resells', 'bundles', 'ship', 'shows', 'vends', 'auction', 'is dealing', 'showcases', 'supply', 'is offering', 'is trading-in', 'publicity campaign', 'will offer up', 'marketing campaign', 'publish', 'pitch', 'open', 'will exhibit', 'pushes', 'featureSell', 'wholesale', 'will export', 'stock', 'is exporting', 'contemplating', 'is stocking', 'offering', 'trades-in', 'highlight', 'will stock', 'share', 'is inventorying', 'show', 'deliver', 'will restock', 'lists', 'is broadcasting', 'subscribe', 'is distributing', 'will highlight', 'will trade', 'engage', 'is retailing', 'is providing', 'customize', 'will broadcast', 'trade', 'find', 'offer', 'will merchandise', 'thinking', 'is pitching', 'is merchandising', 'is listing', 'will show', 'will publish', 'is sharing', 'is marketing', 'is promoting', 'will clear', 'auction off', 'is trading', 'seller_verbs', 'is vending', 'expand', 'open to', 'distribute', 'will market', 'prioritize', 'will supply', 'is posting', 'trades', 'retails', 'display', 'is offering up', 'provides', 'restocks', 'distributes', 'displays', 'is displaying', 'advertises']))

# %%
seller_intent=list(set(['value', 'will execute accounts', 'retail managers', 'will deal', 'is parting with', 'ecommerce entrepreneurs', 'influencer marketing managers', 'advertise', 'lets go of', 'is transferring ownership', 'will part with', 'is removing', 'offer to sell', 'media planners', 'sales operations manager', 'is manufacturing', 'is creating products', 'craftsperson', 'sells items', 'retail business owner', 'marketing channel managers', 'sales strategist', 'marketplace seller', 'marketing managers', 'online marketers', 'marketing performance analysts', 'vintage guitar', 'sells', 'listing for sale', 'business owner', 'small business owner', 'retail store owner', 'is listing on', 'is retailing online', 'post for sale', 'account executive', 'lead generation coordinator', 'selling items', 'will manage inventory', 'customer relations coordinators', 'providing', 'auctions', 'leave', 'sells assets', 'marketing automation specialists', 'is strategizing sales', 'is selling off', 'marketing communications managers', 'will merchant', 'will sell now', 'shopkeepers', 'will sell belongings', 'is selling assets', 'reward', 'affiliate marketing manager', 'distributors', 'parts with', 'social media marketers', 'content marketing coordinators', 'media planner', 'lead generation coordinators', 'wholesalers', 'removedfind a buyer', 'key account managers', 'marketing metrics coordinators', 'will distribute', 'marketing strategist', 'is marketing online', 'hobbyist sellers', 'creators of products', 'is disposing of', 'is coordinating sales', 'will analyze marketing', 'will sell merchandise', 'sales analysts', 'sales leaders', 'email marketing coordinators', 'marketing ROI coordinators', 'sales support specialist', 'store managers', 'customer feedback analysts', 'producers', 'key account manager', 'will import', 'sales strategists', 'will manage advertising', 'sales managers', 'will buy media', 'selling off', 'will sell goods', 'want to sell', 'producers of goods', 'client success managers', 'is managing stores', 'will direct sales', 'wholesaler', 'sales operations managers', 'is managing imports', 'making a sale', 'will dispose of', 'will sell out', 'social media manager', 'is exporting', 'business seller', 'trying to sell', 'business owners', 'will sell a', 'is entrepreneuring', 'will lead sales', 'subscribe', 'is distributing', 'marketing budget coordinator', 'is selling now', 'sales analyst', 'marketing technology specialist', 'seller', 'is selling belongings', 'find', 'is merchandising', 'is directing sales', 'sales', 'marketing campaign coordinator', 'will sell properties', 'advertising manager', 'lists for sale', 'disposes of', 'removes', 'sales representatives', 'sales executives', 'territory sales manager', 'will supply', 'retail manager', 'marketing analyst', 'is selling possessions', 'marketing coordinator', 'will sell my', 'ready to sell', 'retailers', 'sold out of', 'craftspeople', 'branch manager', 'is leading sales', 'will represent sales', 'advertising specialists', 'advertising managers', 'is selling items', 'dropshippers', 'is selling products', 'business development managers', 'conversion rate optimizers', 'marketing specialists', 'digital marketers', 'marketing metrics analysts', 'startup founders', 'will manufacture', 'lead generation specialist', 'marketing performance analyst', 'sold out', 'list for sale', 'brand owners', 'sales coach', 'supplier', 'offering for sale', 'social media marketer', 'franchise owners', 'sales representative', 'social media managers', 'will retail', 'client success specialist', 'selling assets', 'marketing campaign managers', 'list on', 'marketing performance coordinator', 'provide', 'marketing ROI coordinator', 'pay-per-click (PPC) specialists', 'is coordinating advertising', 'auctioneer', 'small business owners', 'conversion rate optimizer', 'is representing sales', 'brick-and-mortar retailers', 'sell my', 'conversion rate coordinators', 'is managing exports', 'is wholesaling', 'listed for sale', 'selling my', 'content creators', 'sold off', 'customer support specialist', 'sell', 'email marketing coordinator', 'will create content', 'is crafting', 'is marketing digitally', 'sells out of', 'brand advocates', 'will sell possessions', 'will manage sales', 'customer support specialists', 'letting go of', 'sales consultant', 'is managing branches', 'is dropshipping', 'is managing retail', 'exporters', 'looks to sell', 'restocking', 'auctioning', 'brand ambassadors', 'attempting to sell', 'is selling out', 'regional sales manager', 'business sellers', 'looking to sell', 'local business owners', 'import managers', 'marketing communications coordinator', 'client success manager', 'store manager', 'digital marketer', 'offers for sale', 'selling possessions', 'customer feedback specialists', 'will sell off', 'brand evangelist', 'selling products', 'producer of goods', 'will export', 'sells merchandise', 'brand owner', 'sales coordinators', 'sells off', 'online retailers', 'selling goods', 'seller on marketplace', 'is selling goods', 'deliver', 'dispose of', 'client success specialists', 'will sell items', 'reseller', 'will create products', 'online marketer', 'customer relations manager', 'parting with', 'will coordinate advertising', 'sell off', 'sell now', 'will sell assets', 'sales specialist', 'offering web design services', 'PPC coordinator', 'contact', 'store owner', 'selling merchandise', 'will plan media', 'selling artwork', 'media buyers', 'showcase my portfolio', 'is vending', 'branch managers', 'social media coordinator', 'retail store owners', 'will produce goods', 'sellers', 'marketing channel coordinator', 'wholesale distributor', 'private label sellers', 'marketing technology specialists', 'customer relations managers', 'lead generation specialists', 'will sell', 'is coordinating marketing', 'marketing manager', 'will strategize sales', 'considering selling', 'will coordinate marketing', 'makes a sale', 'will strategize marketing', 'shopkeeper', 'will manage exports', 'exporter', 'regional sales managers', 'will develop business', 'sales consultants', 'know', 'is coaching sales', 'sells possessions', 'distributor', 'is producing', 'will vendor', 'store owners', 'marketing specialist', 'is managing inventory', 'content marketing manager', 'transfers ownership', 'will coach sales', 'markets for sale', 'antique book collection', 'sellers on marketplace', 'social media coordinators', 'resellers', 'marketing strategists', 'will market digitally', 'will execute sales', 'sales manager', 'import manager', 'online retailer', 'content creator', 'ecommerce sellers', 'brand manager', 'affiliate marketing managers', 'will entrepreneur', 'export managers', 'inventory managers', 'will produce', 'customer relations coordinator', 'account executives', 'marketing metrics coordinator', 'retail business owners', 'hobbyist seller', 'sells my', 'is managing accounts', 'email marketing manager', 'sells belongings', 'will manage stores', 'is developing business', 'account manager', 'influencer marketing coordinators', 'influencer marketing coordinator', 'will manage retail', 'sells properties', 'affiliate marketing coordinators', 'marketing ROI analysts', 'wants to sell', 'posts for sale', 'is managing sales', 'will transfer ownership', 'sales support specialists', 'content marketing managers', 'will manage imports', 'auctioneers', 'customer experience managers', 'advertising coordinators', 'remove', 'will sell products', 'is executing sales', 'transferring ownership', 'dealer', 'is dealing', 'auction', 'vendors', 'merchants', 'retailer', 'marketing campaign manager', 'will remove', 'will advocate', 'creator of products', 'sells goods', 'manufacturing business owners', 'customer advocacy specialists', 'media buyer', 'ecommerce seller', 'brand advocate', 'conversion rate coordinator', 'marketing coordinators', 'will dropship', 'customer experience manager', 'merchant', 'is planning media', 'is selling merchandise', 'export manager', 'sells products', 'is analyzing sales', 'advertising coordinator', 'local business owner', 'is producing goods', 'dropshipper', 'startup founder', 'marketing analysts', 'offer for sale', 'marketing channel manager', 'inventory manager', 'advertise for sale', 'marketing channel coordinators', 'is strategizing marketing', 'content marketing coordinator', 'boutique owners', 'is supplying', 'marketing communications coordinators', 'attempts to sell', 'franchise owner', 'marketing communications manager', 'is selling', 'sales directors', 'brick-and-mortar retailer', 'is auctioneering', 'planning to list', 'marketing budget analysts', 'will shopkeep', 'exploring selling', 'dealers', 'PPC coordinators', 'is managing marketing', 'is buying media', 'advertised for sale', 'accept', 'brand managers', 'entrepreneurs', 'offered for sale', 'is managing advertising', 'is shopkeeping', 'is creating content', 'list', 'brand ambassador', 'sale', 'importers', 'marketing performance coordinators', 'customer feedback specialist', 'update', 'selling belongings', 'market for sale', 'is distributing wholesale', 'ecommerce entrepreneur', 'is selling my', 'marketing automation specialist', 'advertises for sale', 'customer advocacy specialist', 'will auctioneer', 'will market online', 'handmade jewelry onlineoffering', 'importer', 'vendor', 'updatesell', 'boutique owner', 'customer advocacy managers', 'will wholesale', 'affiliate marketing coordinator', 'account managers', 'promote', 'selling a', 'sales team leader', 'sales coordinator', 'sales executive', 'wholesale distributors', 'selling properties', 'will manage accounts', 'will distribute wholesale', 'is selling a', 'is reselling', 'suppliers', 'communicate', 'tries to sell', 'is selling properties', 'business development manager', 'private label seller', 'is importing', 'is executing accounts', 'will craft', 'will resell', 'marketing budget analyst', 'manufacturers', 'is auctioning', 'will manage marketing', 'territory sales managers', 'marketing metrics analyst', 'will retail online', 'pay-per-click (PPC) specialist', 'marketing budget coordinators', 'will auction', 'specialize', 'sells out', 'extra cash', 'sold', 'will list on', 'lists on', 'will analyze sales', 'open', 'sales specialists', 'sales director', 'sales leader', 'local art exhibitions', 'is analyzing marketing', 'entrepreneur', 'will coordinate sales', 'customer feedback analyst', 'producer', 'engage', 'is retailing', 'customize', 'sells now', 'advertising for sale', 'influencer marketing manager', 'selling', 'will manage branches', 'advertising specialist', 'marketing ROI analyst', 'brand evangelists', 'manufacturer', 'manufacturing business owner', 'email marketing managers', 'marketplace sellers', 'expand', 'offers to sell', 'sales team leaders', 'removesfind a buyer', 'sales coaches', 'customer advocacy manager', 'prioritize', 'marketing campaign coordinators']))

# %%
intent_suffixes = [ 'Myntra', 'jabong', 'amazon', 'ajio', 'shopsee','shopsy',"shopse",'nykaa','flipkart', 'meesho', 'misho', "offer", "deal", "discount", "coupon", "sale", "order", "shop", "acquire", "get", "obtain", "procure", "acquisition", "shopping", "buying", "purchasing",   "ordering" ]

# %% [markdown]
# #### Adding into the Excel file

# %%
print("buyer_intent",len(buyer_intent),
"\nbuyer_verbs",len(buyer_verbs),
"\nproducts",len(products),
"\nseller_intent",len(seller_intent),
"\nseller_verbs",len(seller_verbs),
"\nad_campaigns",len(ad_campaigns),
"\nnegative_verbs",len(negative_verbs),
"\nintent_suffixes",len(intent_suffixes))
# Out:
# buyer_intent 135
# buyer_verbs 77
# products 654
# seller_intent 512
# seller_verbs 201
# ad_campaigns 43
# negative_verbs 80
# intent_suffixes 27

# %%
wb=op.load_workbook("training_intent_samples.xlsx")
ws=wb.active

# %%
ws.cell(1,1).value="buyer_intent"
ws.cell(1,2).value="buyer_verbs"
ws.cell(1,3).value="products"
ws.cell(1,4).value="seller_intent"
ws.cell(1,5).value="seller_verbs"
ws.cell(1,6).value="ad_campaigns"
ws.cell(1,7).value="negative_verbs"
ws.cell(1,8).value="intent_suffixes"


# Population traing Dataset
for b in range(1,len(buyer_intent)):
    ws.cell(b+1,1).value=buyer_intent[b-1]
    
for b in range(1,len(buyer_verbs)):
    ws.cell(b+1,2).value=buyer_verbs[b-1]
    
    
for p in range(1,len(products)):
    ws.cell(p+1,3).value=products[p-1]
    
for s in range(1,len(seller_intent)):
    ws.cell(s+1,4).value=seller_intent[s-1]
    
for s in range(1,len(seller_verbs)):
    ws.cell(s+1,5).value=seller_verbs[s-1]
    

for s in range(1,len(ad_campaigns)):
    ws.cell(s+1,6).value=ad_campaigns[s-1]
    
for s in range(1,len(negative_verbs)):
    ws.cell(s+1,7).value=negative_verbs[s-1]
    
for s in range(1,len(intent_suffixes)):
    ws.cell(s+1,8).value=intent_suffixes[s-1]


wb.save("training_intent_samples.xlsx")
wb.close()
